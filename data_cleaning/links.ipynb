# %%
import pandas as pd
import numpy as np

links = pd.read_csv('../data/raw_data/links.csv')

# %%
links.head()
links.shape
links.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  27278 non-null  int64
#  1   imdbId   27278 non-null  int64
#  2   tmdbId   27026 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 639.5 KB

# %%
links.isna().sum()
# Out:
# movieId      0
# imdbId       0
# tmdbId     252
# dtype: int64

# %%
links["movieId"].duplicated().sum()
# Out:
# np.int64(0)

# %%
links["imdbId"].dropna().astype(int).describe()
# Out:
# count    2.727800e+04
# mean     5.781860e+05
# std      7.804707e+05
# min      5.000000e+00
# 25%      7.741725e+04
# 50%      1.524350e+05
# 75%      9.062715e+05
# max      4.530184e+06
# Name: imdbId, dtype: float64

# %%
links["tmdbId"].dropna().astype(int).describe()
# Out:
# count     27026.000000
# mean      63846.683083
# std       69862.134497
# min           2.000000
# 25%       15936.500000
# 50%       39468.500000
# 75%       82504.000000
# max      421510.000000
# Name: tmdbId, dtype: float64

# %%
links["imdbId"] = links["imdbId"].astype("Int64")
links["tmdbId"] = links["tmdbId"].astype("Int64")

# %%
links["movieId"].nunique()
# Out:
# 27278

# %%
links.to_csv(
    "../data/cleaned_data/links_clean.csv",
    index=False
)
